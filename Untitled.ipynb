# %%
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

# %matplotlib inline
pil_im = Image.open('sample_images/dog_2.jpeg', 'r')
plt.figure()
plt.imshow(np.asarray(pil_im))
plt.figure()
imshow(np.asarray(pil_im))
